# %%
import pandas as pd
import geojson

# %%
#be careful running cell, uses a lot of memory
geojsonlocation = "./Data/Geojson/ConDistricts"
geoyears = [2012,2016,2020]
for gyear in geoyears:
    geofile = geojsonlocation+str(gyear)+".geojson"
    with open(geofile, 'r') as f:
        geojson_data = geojson.load(f)
        print(geojson_data)

# %%
elecdf = pd.read_csv("./Data/election_results.csv")

# %%
elecdict = elecdf.to_dict('records')
elecdict
# Out:
# [{'election_year': 1868,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 851,
#   'dem_nominee': 'Horatio Seymour',
#   'rep_votes': 1505,
#   'rep_nominee': 'Ulysses S. Grant',
#   'county_end_date': nan},
#  {'election_year': 1872,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 669,
#   'dem_nominee': 'Horace Greeley',
#   'rep_votes': 1593,
#   'rep_nominee': 'Ulysses S. Grant',
#   'county_end_date': nan},
#  {'election_year': 1876,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 804,
#   'dem_nominee': 'Samuel J. Tilden',
#   'rep_votes': 1576,
#   'rep_nominee': 'Rutherford B. Hayes',
#   'county_end_date': nan},
#  {'election_year': 1880,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 978,
#   'dem_nominee': 'Winfield Scott Hancock',
#   'rep_votes': 974,
#   'rep_nominee': 'James A. Garfield',
#   'county_end_date': nan},
#  {'election_year': 1884,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 911,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 877,
#   'rep_nominee': 'James G. Blaine',
#   'county_end_date': nan},
#  {'election_year': 1888,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 893,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 519,
#   'rep_nominee': 'Benjamin Harrison',
#   'county_end_date': nan},
#  {'election_year': 1892,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 926,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 81,
#   'rep_nominee': 'Benjamin Harrison',
#   'county_end_date': nan},
#  {'election_year': 1896,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 1232,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 289,
#   'rep_nominee': 'William McKinley',
#   'county_end_date': nan},
#  {'election_year': 1900,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 980,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 537,
#   'rep_nominee': 'William McKinley',
#   'county_end_date': nan},
#  {'election_year': 1904,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 733,
#   'dem_nominee': 'Alton B. Parker',
#   'rep_votes': 73,
#   'rep_nominee': 'Theodore Roosevelt',
#   'county_end_date': nan},
#  {'election_year': 1908,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 655,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 97,
#   'rep_nominee': 'William Howard Taft',
#   'county_end_date': nan},
#  {'election_year': 1912,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 622,
#   'dem_nominee': 'Woodrow Wilson',
#   'rep_votes': 43,
#   'rep_nominee': 'William Howard Taft',
#   'county_end_date': nan},
#  {'election_year': 1916,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 773,
#   'dem_nominee': 'Woodrow Wilson',
#   'rep_votes': 99,
#   'rep_nominee': 'Charles Evan Hughes',
#   'county_end_date': nan},
#  {'election_year': 1920,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 918,
#   'dem_nominee': 'James M. Cox',
#   'rep_votes': 210,
#   'rep_nominee': 'Warren G. Harding',
#   'county_end_date': nan},
#  {'election_year': 1924,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 781,
#   'dem_nominee': 'John W. Davis',
#   'rep_votes': 146,
#   'rep_nominee': 'Calvin Cooldige',
#   'county_end_date': nan},
#  {'election_year': 1928,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 883,
#   'dem_nominee': 'Al Smith',
#   'rep_votes': 683,
#   'rep_nominee': 'Herbert Hoover',
#   'county_end_date': nan},
#  {'election_year': 1932,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 1322,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 138,
#   'rep_nominee': 'Herbert Hoover',
#   'county_end_date': nan},
#  {'election_year': 1936,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 1525,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 84,
#   'rep_nominee': 'Alf Landon',
#   'county_end_date': nan},
#  {'election_year': 1940,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 1631,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 99,
#   'rep_nominee': 'Wendell Willkie',
#   'county_end_date': nan},
#  {'election_year': 1944,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 1242,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 117,
#   'rep_nominee': 'Thomes E. Dewey',
#   'county_end_date': nan},
#  {'election_year': 1948,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 1160,
#   'dem_nominee': 'Harry S. Truman',
#   'rep_votes': 110,
#   'rep_nominee': 'Thomes E. Dewey',
#   'county_end_date': nan},
#  {'election_year': 1952,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 1505,
#   'dem_nominee': 'Adlai Stevenson II',
#   'rep_votes': 787,
#   'rep_nominee': 'Dwight D. Eisenhower',
#   'county_end_date': nan},
#  {'election_year': 1956,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 1115,
#   'dem_nominee': 'Adlai Stevenson II',
#   'rep_votes': 857,
#   'rep_nominee': 'Dwight D. Eisenhower',
#   'county_end_date': nan},
#  {'election_year': 1960,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 1324,
#   'dem_nominee': 'John F. Kennedy',
#   'rep_votes': 1153,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1964,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 491,
#   'dem_nominee': 'Lyndon B. Johnson',
#   'rep_votes': 2969,
#   'rep_nominee': 'Barry Goldwater',
#   'county_end_date': nan},
#  {'election_year': 1968,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 5491,
#   'dem_nominee': 'Herbert H. Humphrey',
#   'rep_votes': 597,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1972,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 1593,
#   'dem_nominee': 'George S. McGovern',
#   'rep_votes': 5367,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1976,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 4640,
#   'dem_nominee': 'Jimmy Carter',
#   'rep_votes': 4512,
#   'rep_nominee': 'Gerald Ford',
#   'county_end_date': nan},
#  {'election_year': 1980,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 4295,
#   'dem_nominee': 'Jimmy Carter',
#   'rep_votes': 6292,
#   'rep_nominee': 'Ronald Reagan',
#   'county_end_date': nan},
#  {'election_year': 1984,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 3366,
#   'dem_nominee': 'Walter Mondale',
#   'rep_votes': 8350,
#   'rep_nominee': 'Ronald Reagan',
#   'county_end_date': nan},
#  {'election_year': 1988,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 3667,
#   'dem_nominee': 'Michael Dukakis',
#   'rep_votes': 7828,
#   'rep_nominee': 'George H.W. Bush',
#   'county_end_date': nan},
#  {'election_year': 1992,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 4819,
#   'dem_nominee': 'Bill Clinton',
#   'rep_votes': 8715,
#   'rep_nominee': 'George H.W. Bush',
#   'county_end_date': nan},
#  {'election_year': 1996,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 5015,
#   'dem_nominee': 'Bill Clinton',
#   'rep_votes': 9509,
#   'rep_nominee': 'Bob Dole',
#   'county_end_date': nan},
#  {'election_year': 2000,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 4942,
#   'dem_nominee': 'Al Gore',
#   'rep_votes': 11993,
#   'rep_nominee': 'George W. Bush',
#   'county_end_date': nan},
#  {'election_year': 2004,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 4758,
#   'dem_nominee': 'John F. Kerry',
#   'rep_votes': 15196,
#   'rep_nominee': 'George W. Bush',
#   'county_end_date': nan},
#  {'election_year': 2008,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 6093,
#   'dem_nominee': 'Barack H. Obama',
#   'rep_votes': 17403,
#   'rep_nominee': 'John McCain',
#   'county_end_date': nan},
#  {'election_year': 2012,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 6363,
#   'dem_nominee': 'Barack H. Obama',
#   'rep_votes': 17379,
#   'rep_nominee': 'Mitt Romney',
#   'county_end_date': nan},
#  {'election_year': 2016,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 5936,
#   'dem_nominee': 'Hillary Rodham Clinton',
#   'rep_votes': 18172,
#   'rep_nominee': 'Donald Trump',
#   'county_end_date': nan},
#  {'election_year': 2020,
#   'fips': 1001.0,
#   'county_name': 'AUTAUGA',
#   'state': 'AL',
#   'dem_votes': 7503,
#   'dem_nominee': 'Joe Biden',
#   'rep_votes': 19838,
#   'rep_nominee': 'Donald Trump',
#   'county_end_date': nan},
#  {'election_year': 1868,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 673,
#   'dem_nominee': 'Horatio Seymour',
#   'rep_votes': 558,
#   'rep_nominee': 'Ulysses S. Grant',
#   'county_end_date': nan},
#  {'election_year': 1872,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 549,
#   'dem_nominee': 'Horace Greeley',
#   'rep_votes': 707,
#   'rep_nominee': 'Ulysses S. Grant',
#   'county_end_date': nan},
#  {'election_year': 1876,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 789,
#   'dem_nominee': 'Samuel J. Tilden',
#   'rep_votes': 662,
#   'rep_nominee': 'Rutherford B. Hayes',
#   'county_end_date': nan},
#  {'election_year': 1880,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 767,
#   'dem_nominee': 'Winfield Scott Hancock',
#   'rep_votes': 663,
#   'rep_nominee': 'James A. Garfield',
#   'county_end_date': nan},
#  {'election_year': 1884,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 776,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 702,
#   'rep_nominee': 'James G. Blaine',
#   'county_end_date': nan},
#  {'election_year': 1888,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 724,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 547,
#   'rep_nominee': 'Benjamin Harrison',
#   'county_end_date': nan},
#  {'election_year': 1892,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 912,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 382,
#   'rep_nominee': 'Benjamin Harrison',
#   'county_end_date': nan},
#  {'election_year': 1896,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 704,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 404,
#   'rep_nominee': 'William McKinley',
#   'county_end_date': nan},
#  {'election_year': 1900,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 444,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 396,
#   'rep_nominee': 'William McKinley',
#   'county_end_date': nan},
#  {'election_year': 1904,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 454,
#   'dem_nominee': 'Alton B. Parker',
#   'rep_votes': 126,
#   'rep_nominee': 'Theodore Roosevelt',
#   'county_end_date': nan},
#  {'election_year': 1908,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 439,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 109,
#   'rep_nominee': 'William Howard Taft',
#   'county_end_date': nan},
#  {'election_year': 1912,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 623,
#   'dem_nominee': 'Woodrow Wilson',
#   'rep_votes': 37,
#   'rep_nominee': 'William Howard Taft',
#   'county_end_date': nan},
#  {'election_year': 1916,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 766,
#   'dem_nominee': 'Woodrow Wilson',
#   'rep_votes': 216,
#   'rep_nominee': 'Charles Evan Hughes',
#   'county_end_date': nan},
#  {'election_year': 1920,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 1230,
#   'dem_nominee': 'James M. Cox',
#   'rep_votes': 556,
#   'rep_nominee': 'Warren G. Harding',
#   'county_end_date': nan},
#  {'election_year': 1924,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 1023,
#   'dem_nominee': 'John W. Davis',
#   'rep_votes': 549,
#   'rep_nominee': 'Calvin Cooldige',
#   'county_end_date': nan},
#  {'election_year': 1928,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 1317,
#   'dem_nominee': 'Al Smith',
#   'rep_votes': 1388,
#   'rep_nominee': 'Herbert Hoover',
#   'county_end_date': nan},
#  {'election_year': 1932,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 2101,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 543,
#   'rep_nominee': 'Herbert Hoover',
#   'county_end_date': nan},
#  {'election_year': 1936,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 2335,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 434,
#   'rep_nominee': 'Alf Landon',
#   'county_end_date': nan},
#  {'election_year': 1940,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 2679,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 611,
#   'rep_nominee': 'Wendell Willkie',
#   'county_end_date': nan},
#  {'election_year': 1944,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 2004,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 695,
#   'rep_nominee': 'Thomes E. Dewey',
#   'county_end_date': nan},
#  {'election_year': 1948,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 2577,
#   'dem_nominee': 'Harry S. Truman',
#   'rep_votes': 767,
#   'rep_nominee': 'Thomes E. Dewey',
#   'county_end_date': nan},
#  {'election_year': 1952,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 3386,
#   'dem_nominee': 'Adlai Stevenson II',
#   'rep_votes': 3179,
#   'rep_nominee': 'Dwight D. Eisenhower',
#   'county_end_date': nan},
#  {'election_year': 1956,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 3877,
#   'dem_nominee': 'Adlai Stevenson II',
#   'rep_votes': 4293,
#   'rep_nominee': 'Dwight D. Eisenhower',
#   'county_end_date': nan},
#  {'election_year': 1960,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 5647,
#   'dem_nominee': 'John F. Kennedy',
#   'rep_votes': 4771,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1964,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 2530,
#   'dem_nominee': 'Lyndon B. Johnson',
#   'rep_votes': 10870,
#   'rep_nominee': 'Barry Goldwater',
#   'county_end_date': nan},
#  {'election_year': 1968,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 14346,
#   'dem_nominee': 'Herbert H. Humphrey',
#   'rep_votes': 2157,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1972,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 2923,
#   'dem_nominee': 'George S. McGovern',
#   'rep_votes': 15104,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1976,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 9191,
#   'dem_nominee': 'Jimmy Carter',
#   'rep_votes': 13256,
#   'rep_nominee': 'Gerald Ford',
#   'county_end_date': nan},
#  {'election_year': 1980,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 8448,
#   'dem_nominee': 'Jimmy Carter',
#   'rep_votes': 18652,
#   'rep_nominee': 'Ronald Reagan',
#   'county_end_date': nan},
#  {'election_year': 1984,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 7272,
#   'dem_nominee': 'Walter Mondale',
#   'rep_votes': 24964,
#   'rep_nominee': 'Ronald Reagan',
#   'county_end_date': nan},
#  {'election_year': 1988,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 9271,
#   'dem_nominee': 'Michael Dukakis',
#   'rep_votes': 25933,
#   'rep_nominee': 'George H.W. Bush',
#   'county_end_date': nan},
#  {'election_year': 1992,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 12195,
#   'dem_nominee': 'Bill Clinton',
#   'rep_votes': 26270,
#   'rep_nominee': 'George H.W. Bush',
#   'county_end_date': nan},
#  {'election_year': 1996,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 12776,
#   'dem_nominee': 'Bill Clinton',
#   'rep_votes': 29487,
#   'rep_nominee': 'Bob Dole',
#   'county_end_date': nan},
#  {'election_year': 2000,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 13997,
#   'dem_nominee': 'Al Gore',
#   'rep_votes': 40872,
#   'rep_nominee': 'George W. Bush',
#   'county_end_date': nan},
#  {'election_year': 2004,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 15599,
#   'dem_nominee': 'John F. Kerry',
#   'rep_votes': 52971,
#   'rep_nominee': 'George W. Bush',
#   'county_end_date': nan},
#  {'election_year': 2008,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 19386,
#   'dem_nominee': 'Barack H. Obama',
#   'rep_votes': 61271,
#   'rep_nominee': 'John McCain',
#   'county_end_date': nan},
#  {'election_year': 2012,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 18424,
#   'dem_nominee': 'Barack H. Obama',
#   'rep_votes': 66016,
#   'rep_nominee': 'Mitt Romney',
#   'county_end_date': nan},
#  {'election_year': 2016,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 18458,
#   'dem_nominee': 'Hillary Rodham Clinton',
#   'rep_votes': 72883,
#   'rep_nominee': 'Donald Trump',
#   'county_end_date': nan},
#  {'election_year': 2020,
#   'fips': 1003.0,
#   'county_name': 'BALDWIN',
#   'state': 'AL',
#   'dem_votes': 24578,
#   'dem_nominee': 'Joe Biden',
#   'rep_votes': 83544,
#   'rep_nominee': 'Donald Trump',
#   'county_end_date': nan},
#  {'election_year': 1868,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 2210,
#   'dem_nominee': 'Horatio Seymour',
#   'rep_votes': 3168,
#   'rep_nominee': 'Ulysses S. Grant',
#   'county_end_date': nan},
#  {'election_year': 1872,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 2320,
#   'dem_nominee': 'Horace Greeley',
#   'rep_votes': 2756,
#   'rep_nominee': 'Ulysses S. Grant',
#   'county_end_date': nan},
#  {'election_year': 1876,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 3594,
#   'dem_nominee': 'Samuel J. Tilden',
#   'rep_votes': 162,
#   'rep_nominee': 'Rutherford B. Hayes',
#   'county_end_date': nan},
#  {'election_year': 1880,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 2753,
#   'dem_nominee': 'Winfield Scott Hancock',
#   'rep_votes': 1200,
#   'rep_nominee': 'James A. Garfield',
#   'county_end_date': nan},
#  {'election_year': 1884,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 2122,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 700,
#   'rep_nominee': 'James G. Blaine',
#   'county_end_date': nan},
#  {'election_year': 1888,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 3530,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 452,
#   'rep_nominee': 'Benjamin Harrison',
#   'county_end_date': nan},
#  {'election_year': 1892,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 4315,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 19,
#   'rep_nominee': 'Benjamin Harrison',
#   'county_end_date': nan},
#  {'election_year': 1896,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 2215,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 1437,
#   'rep_nominee': 'William McKinley',
#   'county_end_date': nan},
#  {'election_year': 1900,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 2714,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 272,
#   'rep_nominee': 'William McKinley',
#   'county_end_date': nan},
#  {'election_year': 1904,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 1356,
#   'dem_nominee': 'Alton B. Parker',
#   'rep_votes': 49,
#   'rep_nominee': 'Theodore Roosevelt',
#   'county_end_date': nan},
#  {'election_year': 1908,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 1303,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 43,
#   'rep_nominee': 'William Howard Taft',
#   'county_end_date': nan},
#  {'election_year': 1912,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 1155,
#   'dem_nominee': 'Woodrow Wilson',
#   'rep_votes': 18,
#   'rep_nominee': 'William Howard Taft',
#   'county_end_date': nan},
#  {'election_year': 1916,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 1235,
#   'dem_nominee': 'Woodrow Wilson',
#   'rep_votes': 45,
#   'rep_nominee': 'Charles Evan Hughes',
#   'county_end_date': nan},
#  {'election_year': 1920,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 1568,
#   'dem_nominee': 'James M. Cox',
#   'rep_votes': 203,
#   'rep_nominee': 'Warren G. Harding',
#   'county_end_date': nan},
#  {'election_year': 1924,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 1340,
#   'dem_nominee': 'John W. Davis',
#   'rep_votes': 78,
#   'rep_nominee': 'Calvin Cooldige',
#   'county_end_date': nan},
#  {'election_year': 1928,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 1506,
#   'dem_nominee': 'Al Smith',
#   'rep_votes': 845,
#   'rep_nominee': 'Herbert Hoover',
#   'county_end_date': nan},
#  {'election_year': 1932,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 2207,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 64,
#   'rep_nominee': 'Herbert Hoover',
#   'county_end_date': nan},
#  {'election_year': 1936,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 2386,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 50,
#   'rep_nominee': 'Alf Landon',
#   'county_end_date': nan},
#  {'election_year': 1940,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 2328,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 90,
#   'rep_nominee': 'Wendell Willkie',
#   'county_end_date': nan},
#  {'election_year': 1944,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 2237,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 67,
#   'rep_nominee': 'Thomes E. Dewey',
#   'county_end_date': nan},
#  {'election_year': 1948,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 1679,
#   'dem_nominee': 'Harry S. Truman',
#   'rep_votes': 101,
#   'rep_nominee': 'Thomes E. Dewey',
#   'county_end_date': nan},
#  {'election_year': 1952,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 2250,
#   'dem_nominee': 'Adlai Stevenson II',
#   'rep_votes': 798,
#   'rep_nominee': 'Dwight D. Eisenhower',
#   'county_end_date': nan},
#  {'election_year': 1956,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 2530,
#   'dem_nominee': 'Adlai Stevenson II',
#   'rep_votes': 777,
#   'rep_nominee': 'Dwight D. Eisenhower',
#   'county_end_date': nan},
#  {'election_year': 1960,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 2148,
#   'dem_nominee': 'John F. Kennedy',
#   'rep_votes': 1165,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1964,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 978,
#   'dem_nominee': 'Lyndon B. Johnson',
#   'rep_votes': 3853,
#   'rep_nominee': 'Barry Goldwater',
#   'county_end_date': nan},
#  {'election_year': 1968,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 5483,
#   'dem_nominee': 'Herbert H. Humphrey',
#   'rep_votes': 390,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1972,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 1846,
#   'dem_nominee': 'George S. McGovern',
#   'rep_votes': 4985,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1976,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 4730,
#   'dem_nominee': 'Jimmy Carter',
#   'rep_votes': 3758,
#   'rep_nominee': 'Gerald Ford',
#   'county_end_date': nan},
#  {'election_year': 1980,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 4458,
#   'dem_nominee': 'Jimmy Carter',
#   'rep_votes': 4171,
#   'rep_nominee': 'Ronald Reagan',
#   'county_end_date': nan},
#  {'election_year': 1984,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 4591,
#   'dem_nominee': 'Walter Mondale',
#   'rep_votes': 5459,
#   'rep_nominee': 'Ronald Reagan',
#   'county_end_date': nan},
#  {'election_year': 1988,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 3836,
#   'dem_nominee': 'Michael Dukakis',
#   'rep_votes': 4958,
#   'rep_nominee': 'George H.W. Bush',
#   'county_end_date': nan},
#  {'election_year': 1992,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 4836,
#   'dem_nominee': 'Bill Clinton',
#   'rep_votes': 4475,
#   'rep_nominee': 'George H.W. Bush',
#   'county_end_date': nan},
#  {'election_year': 1996,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 4787,
#   'dem_nominee': 'Bill Clinton',
#   'rep_votes': 3627,
#   'rep_nominee': 'Bob Dole',
#   'county_end_date': nan},
#  {'election_year': 2000,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 5188,
#   'dem_nominee': 'Al Gore',
#   'rep_votes': 5096,
#   'rep_nominee': 'George W. Bush',
#   'county_end_date': nan},
#  {'election_year': 2004,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 4832,
#   'dem_nominee': 'John F. Kerry',
#   'rep_votes': 5899,
#   'rep_nominee': 'George W. Bush',
#   'county_end_date': nan},
#  {'election_year': 2008,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 5697,
#   'dem_nominee': 'Barack H. Obama',
#   'rep_votes': 5866,
#   'rep_nominee': 'John McCain',
#   'county_end_date': nan},
#  {'election_year': 2012,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 5912,
#   'dem_nominee': 'Barack H. Obama',
#   'rep_votes': 5550,
#   'rep_nominee': 'Mitt Romney',
#   'county_end_date': nan},
#  {'election_year': 2016,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 4871,
#   'dem_nominee': 'Hillary Rodham Clinton',
#   'rep_votes': 5454,
#   'rep_nominee': 'Donald Trump',
#   'county_end_date': nan},
#  {'election_year': 2020,
#   'fips': 1005.0,
#   'county_name': 'BARBOUR',
#   'state': 'AL',
#   'dem_votes': 4816,
#   'dem_nominee': 'Joe Biden',
#   'rep_votes': 5622,
#   'rep_nominee': 'Donald Trump',
#   'county_end_date': nan},
#  {'election_year': 1868,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 744,
#   'dem_nominee': 'Horatio Seymour',
#   'rep_votes': 492,
#   'rep_nominee': 'Ulysses S. Grant',
#   'county_end_date': nan},
#  {'election_year': 1872,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 789,
#   'dem_nominee': 'Horace Greeley',
#   'rep_votes': 433,
#   'rep_nominee': 'Ulysses S. Grant',
#   'county_end_date': nan},
#  {'election_year': 1876,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 890,
#   'dem_nominee': 'Samuel J. Tilden',
#   'rep_votes': 333,
#   'rep_nominee': 'Rutherford B. Hayes',
#   'county_end_date': nan},
#  {'election_year': 1880,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 737,
#   'dem_nominee': 'Winfield Scott Hancock',
#   'rep_votes': 106,
#   'rep_nominee': 'James A. Garfield',
#   'county_end_date': nan},
#  {'election_year': 1884,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 622,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 275,
#   'rep_nominee': 'James G. Blaine',
#   'county_end_date': nan},
#  {'election_year': 1888,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 960,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 657,
#   'rep_nominee': 'Benjamin Harrison',
#   'county_end_date': nan},
#  {'election_year': 1892,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 1152,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 22,
#   'rep_nominee': 'Benjamin Harrison',
#   'county_end_date': nan},
#  {'election_year': 1896,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 984,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 650,
#   'rep_nominee': 'William McKinley',
#   'county_end_date': nan},
#  {'election_year': 1900,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 725,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 482,
#   'rep_nominee': 'William McKinley',
#   'county_end_date': nan},
#  {'election_year': 1904,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 1085,
#   'dem_nominee': 'Alton B. Parker',
#   'rep_votes': 155,
#   'rep_nominee': 'Theodore Roosevelt',
#   'county_end_date': nan},
#  {'election_year': 1908,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 670,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 139,
#   'rep_nominee': 'William Howard Taft',
#   'county_end_date': nan},
#  {'election_year': 1912,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 820,
#   'dem_nominee': 'Woodrow Wilson',
#   'rep_votes': 40,
#   'rep_nominee': 'William Howard Taft',
#   'county_end_date': nan},
#  {'election_year': 1916,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 1247,
#   'dem_nominee': 'Woodrow Wilson',
#   'rep_votes': 217,
#   'rep_nominee': 'Charles Evan Hughes',
#   'county_end_date': nan},
#  {'election_year': 1920,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 1643,
#   'dem_nominee': 'James M. Cox',
#   'rep_votes': 364,
#   'rep_nominee': 'Warren G. Harding',
#   'county_end_date': nan},
#  {'election_year': 1924,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 875,
#   'dem_nominee': 'John W. Davis',
#   'rep_votes': 251,
#   'rep_nominee': 'Calvin Cooldige',
#   'county_end_date': nan},
#  {'election_year': 1928,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 1188,
#   'dem_nominee': 'Al Smith',
#   'rep_votes': 1003,
#   'rep_nominee': 'Herbert Hoover',
#   'county_end_date': nan},
#  {'election_year': 1932,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 1636,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 145,
#   'rep_nominee': 'Herbert Hoover',
#   'county_end_date': nan},
#  {'election_year': 1936,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 1868,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 190,
#   'rep_nominee': 'Alf Landon',
#   'county_end_date': nan},
#  {'election_year': 1940,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 1821,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 173,
#   'rep_nominee': 'Wendell Willkie',
#   'county_end_date': nan},
#  {'election_year': 1944,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 1290,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 244,
#   'rep_nominee': 'Thomes E. Dewey',
#   'county_end_date': nan},
#  {'election_year': 1948,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 1188,
#   'dem_nominee': 'Harry S. Truman',
#   'rep_votes': 123,
#   'rep_nominee': 'Thomes E. Dewey',
#   'county_end_date': nan},
#  {'election_year': 1952,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 1971,
#   'dem_nominee': 'Adlai Stevenson II',
#   'rep_votes': 784,
#   'rep_nominee': 'Dwight D. Eisenhower',
#   'county_end_date': nan},
#  {'election_year': 1956,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 1476,
#   'dem_nominee': 'Adlai Stevenson II',
#   'rep_votes': 1004,
#   'rep_nominee': 'Dwight D. Eisenhower',
#   'county_end_date': nan},
#  {'election_year': 1960,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 1697,
#   'dem_nominee': 'John F. Kennedy',
#   'rep_votes': 1049,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1964,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 503,
#   'dem_nominee': 'Lyndon B. Johnson',
#   'rep_votes': 2623,
#   'rep_nominee': 'Barry Goldwater',
#   'county_end_date': nan},
#  {'election_year': 1968,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 3638,
#   'dem_nominee': 'Herbert H. Humphrey',
#   'rep_votes': 260,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1972,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 837,
#   'dem_nominee': 'George S. McGovern',
#   'rep_votes': 3332,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1976,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 2850,
#   'dem_nominee': 'Jimmy Carter',
#   'rep_votes': 1591,
#   'rep_nominee': 'Gerald Ford',
#   'county_end_date': nan},
#  {'election_year': 1980,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 3097,
#   'dem_nominee': 'Jimmy Carter',
#   'rep_votes': 2491,
#   'rep_nominee': 'Ronald Reagan',
#   'county_end_date': nan},
#  {'election_year': 1984,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 2167,
#   'dem_nominee': 'Walter Mondale',
#   'rep_votes': 3487,
#   'rep_nominee': 'Ronald Reagan',
#   'county_end_date': nan},
#  {'election_year': 1988,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 2244,
#   'dem_nominee': 'Michael Dukakis',
#   'rep_votes': 2885,
#   'rep_nominee': 'George H.W. Bush',
#   'county_end_date': nan},
#  {'election_year': 1992,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 2900,
#   'dem_nominee': 'Bill Clinton',
#   'rep_votes': 3124,
#   'rep_nominee': 'George H.W. Bush',
#   'county_end_date': nan},
#  {'election_year': 1996,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 2775,
#   'dem_nominee': 'Bill Clinton',
#   'rep_votes': 3037,
#   'rep_nominee': 'Bob Dole',
#   'county_end_date': nan},
#  {'election_year': 2000,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 2710,
#   'dem_nominee': 'Al Gore',
#   'rep_votes': 4273,
#   'rep_nominee': 'George W. Bush',
#   'county_end_date': nan},
#  {'election_year': 2004,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 2089,
#   'dem_nominee': 'John F. Kerry',
#   'rep_votes': 5472,
#   'rep_nominee': 'George W. Bush',
#   'county_end_date': nan},
#  {'election_year': 2008,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 2299,
#   'dem_nominee': 'Barack H. Obama',
#   'rep_votes': 6262,
#   'rep_nominee': 'John McCain',
#   'county_end_date': nan},
#  {'election_year': 2012,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 2202,
#   'dem_nominee': 'Barack H. Obama',
#   'rep_votes': 6132,
#   'rep_nominee': 'Mitt Romney',
#   'county_end_date': nan},
#  {'election_year': 2016,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 1874,
#   'dem_nominee': 'Hillary Rodham Clinton',
#   'rep_votes': 6738,
#   'rep_nominee': 'Donald Trump',
#   'county_end_date': nan},
#  {'election_year': 2020,
#   'fips': 1007.0,
#   'county_name': 'BIBB',
#   'state': 'AL',
#   'dem_votes': 1986,
#   'dem_nominee': 'Joe Biden',
#   'rep_votes': 7525,
#   'rep_nominee': 'Donald Trump',
#   'county_end_date': nan},
#  {'election_year': 1868,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 461,
#   'dem_nominee': 'Horatio Seymour',
#   'rep_votes': 275,
#   'rep_nominee': 'Ulysses S. Grant',
#   'county_end_date': nan},
#  {'election_year': 1872,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 549,
#   'dem_nominee': 'Horace Greeley',
#   'rep_votes': 276,
#   'rep_nominee': 'Ulysses S. Grant',
#   'county_end_date': nan},
#  {'election_year': 1876,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 1402,
#   'dem_nominee': 'Samuel J. Tilden',
#   'rep_votes': 347,
#   'rep_nominee': 'Rutherford B. Hayes',
#   'county_end_date': nan},
#  {'election_year': 1880,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 1318,
#   'dem_nominee': 'Winfield Scott Hancock',
#   'rep_votes': 260,
#   'rep_nominee': 'James A. Garfield',
#   'county_end_date': nan},
#  {'election_year': 1884,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 1490,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 463,
#   'rep_nominee': 'James G. Blaine',
#   'county_end_date': nan},
#  {'election_year': 1888,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 1873,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 375,
#   'rep_nominee': 'Benjamin Harrison',
#   'county_end_date': nan},
#  {'election_year': 1892,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 1944,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 58,
#   'rep_nominee': 'Benjamin Harrison',
#   'county_end_date': nan},
#  {'election_year': 1896,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 1890,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 2619,
#   'rep_nominee': 'William McKinley',
#   'county_end_date': nan},
#  {'election_year': 1900,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 1484,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 1134,
#   'rep_nominee': 'William McKinley',
#   'county_end_date': nan},
#  {'election_year': 1904,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 1383,
#   'dem_nominee': 'Alton B. Parker',
#   'rep_votes': 910,
#   'rep_nominee': 'Theodore Roosevelt',
#   'county_end_date': nan},
#  {'election_year': 1908,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 1133,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 973,
#   'rep_nominee': 'William Howard Taft',
#   'county_end_date': nan},
#  {'election_year': 1912,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 1121,
#   'dem_nominee': 'Woodrow Wilson',
#   'rep_votes': 567,
#   'rep_nominee': 'William Howard Taft',
#   'county_end_date': nan},
#  {'election_year': 1916,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 1488,
#   'dem_nominee': 'Woodrow Wilson',
#   'rep_votes': 1229,
#   'rep_nominee': 'Charles Evan Hughes',
#   'county_end_date': nan},
#  {'election_year': 1920,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 3535,
#   'dem_nominee': 'James M. Cox',
#   'rep_votes': 3465,
#   'rep_nominee': 'Warren G. Harding',
#   'county_end_date': nan},
#  {'election_year': 1924,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 2083,
#   'dem_nominee': 'John W. Davis',
#   'rep_votes': 1518,
#   'rep_nominee': 'Calvin Cooldige',
#   'county_end_date': nan},
#  {'election_year': 1928,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 1607,
#   'dem_nominee': 'Al Smith',
#   'rep_votes': 1745,
#   'rep_nominee': 'Herbert Hoover',
#   'county_end_date': nan},
#  {'election_year': 1932,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 2232,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 582,
#   'rep_nominee': 'Herbert Hoover',
#   'county_end_date': nan},
#  {'election_year': 1936,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 2788,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 744,
#   'rep_nominee': 'Alf Landon',
#   'county_end_date': nan},
#  {'election_year': 1940,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 2784,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 855,
#   'rep_nominee': 'Wendell Willkie',
#   'county_end_date': nan},
#  {'election_year': 1944,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 2133,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 997,
#   'rep_nominee': 'Thomes E. Dewey',
#   'county_end_date': nan},
#  {'election_year': 1948,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 1768,
#   'dem_nominee': 'Harry S. Truman',
#   'rep_votes': 771,
#   'rep_nominee': 'Thomes E. Dewey',
#   'county_end_date': nan},
#  {'election_year': 1952,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 3161,
#   'dem_nominee': 'Adlai Stevenson II',
#   'rep_votes': 1720,
#   'rep_nominee': 'Dwight D. Eisenhower',
#   'county_end_date': nan},
#  {'election_year': 1956,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 3212,
#   'dem_nominee': 'Adlai Stevenson II',
#   'rep_votes': 2628,
#   'rep_nominee': 'Dwight D. Eisenhower',
#   'county_end_date': nan},
#  {'election_year': 1960,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 3404,
#   'dem_nominee': 'John F. Kennedy',
#   'rep_votes': 2558,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1964,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 2427,
#   'dem_nominee': 'Lyndon B. Johnson',
#   'rep_votes': 4442,
#   'rep_nominee': 'Barry Goldwater',
#   'county_end_date': nan},
#  {'election_year': 1968,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 6518,
#   'dem_nominee': 'Herbert H. Humphrey',
#   'rep_votes': 1996,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1972,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 1582,
#   'dem_nominee': 'George S. McGovern',
#   'rep_votes': 6486,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1976,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 6645,
#   'dem_nominee': 'Jimmy Carter',
#   'rep_votes': 4233,
#   'rep_nominee': 'Gerald Ford',
#   'county_end_date': nan},
#  {'election_year': 1980,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 5656,
#   'dem_nominee': 'Jimmy Carter',
#   'rep_votes': 6819,
#   'rep_nominee': 'Ronald Reagan',
#   'county_end_date': nan},
#  {'election_year': 1984,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 3738,
#   'dem_nominee': 'Walter Mondale',
#   'rep_votes': 8508,
#   'rep_nominee': 'Ronald Reagan',
#   'county_end_date': nan},
#  {'election_year': 1988,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 4485,
#   'dem_nominee': 'Michael Dukakis',
#   'rep_votes': 8754,
#   'rep_nominee': 'George H.W. Bush',
#   'county_end_date': nan},
#  {'election_year': 1992,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 5433,
#   'dem_nominee': 'Bill Clinton',
#   'rep_votes': 8882,
#   'rep_nominee': 'George H.W. Bush',
#   'county_end_date': nan},
#  {'election_year': 1996,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 5061,
#   'dem_nominee': 'Bill Clinton',
#   'rep_votes': 9056,
#   'rep_nominee': 'Bob Dole',
#   'county_end_date': nan},
#  {'election_year': 2000,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 4977,
#   'dem_nominee': 'Al Gore',
#   'rep_votes': 12667,
#   'rep_nominee': 'George W. Bush',
#   'county_end_date': nan},
#  {'election_year': 2004,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 3938,
#   'dem_nominee': 'John F. Kerry',
#   'rep_votes': 17386,
#   'rep_nominee': 'George W. Bush',
#   'county_end_date': nan},
#  {'election_year': 2008,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 3522,
#   'dem_nominee': 'Barack H. Obama',
#   'rep_votes': 20389,
#   'rep_nominee': 'John McCain',
#   'county_end_date': nan},
#  {'election_year': 2012,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 2970,
#   'dem_nominee': 'Barack H. Obama',
#   'rep_votes': 20757,
#   'rep_nominee': 'Mitt Romney',
#   'county_end_date': nan},
#  {'election_year': 2016,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 2156,
#   'dem_nominee': 'Hillary Rodham Clinton',
#   'rep_votes': 22859,
#   'rep_nominee': 'Donald Trump',
#   'county_end_date': nan},
#  {'election_year': 2020,
#   'fips': 1009.0,
#   'county_name': 'BLOUNT',
#   'state': 'AL',
#   'dem_votes': 2640,
#   'dem_nominee': 'Joe Biden',
#   'rep_votes': 24711,
#   'rep_nominee': 'Donald Trump',
#   'county_end_date': nan},
#  {'election_year': 1868,
#   'fips': 1011.0,
#   'county_name': 'BULLOCK',
#   'state': 'AL',
#   'dem_votes': 1634,
#   'dem_nominee': 'Horatio Seymour',
#   'rep_votes': 2103,
#   'rep_nominee': 'Ulysses S. Grant',
#   'county_end_date': nan},
#  {'election_year': 1872,
#   'fips': 1011.0,
#   'county_name': 'BULLOCK',
#   'state': 'AL',
#   'dem_votes': 1225,
#   'dem_nominee': 'Horace Greeley',
#   'rep_votes': 3101,
#   'rep_nominee': 'Ulysses S. Grant',
#   'county_end_date': nan},
#  {'election_year': 1876,
#   'fips': 1011.0,
#   'county_name': 'BULLOCK',
#   'state': 'AL',
#   'dem_votes': 1567,
#   'dem_nominee': 'Samuel J. Tilden',
#   'rep_votes': 959,
#   'rep_nominee': 'Rutherford B. Hayes',
#   'county_end_date': nan},
#  {'election_year': 1880,
#   'fips': 1011.0,
#   'county_name': 'BULLOCK',
#   'state': 'AL',
#   'dem_votes': 125,
#   'dem_nominee': 'Winfield Scott Hancock',
#   'rep_votes': 656,
#   'rep_nominee': 'James A. Garfield',
#   'county_end_date': nan},
#  {'election_year': 1884,
#   'fips': 1011.0,
#   'county_name': 'BULLOCK',
#   'state': 'AL',
#   'dem_votes': 580,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 296,
#   'rep_nominee': 'James G. Blaine',
#   'county_end_date': nan},
#  {'election_year': 1888,
#   'fips': 1011.0,
#   'county_name': 'BULLOCK',
#   'state': 'AL',
#   'dem_votes': 716,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 465,
#   'rep_nominee': 'Benjamin Harrison',
#   'county_end_date': nan},
#  {'election_year': 1892,
#   'fips': 1011.0,
#   'county_name': 'BULLOCK',
#   'state': 'AL',
#   'dem_votes': 1844,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 75,
#   'rep_nominee': 'Benjamin Harrison',
#   'county_end_date': nan},
#  {'election_year': 1896,
#   'fips': 1011.0,
#   'county_name': 'BULLOCK',
#   'state': 'AL',
#   'dem_votes': 1844,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 749,
#   'rep_nominee': 'William McKinley',
#   'county_end_date': nan},
#  {'election_year': 1900,
#   'fips': 1011.0,
#   'county_name': 'BULLOCK',
#   'state': 'AL',
#   'dem_votes': 1586,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 269,
#   'rep_nominee': 'William McKinley',
#   'county_end_date': nan},
#  {'election_year': 1904,
#   'fips': 1011.0,
#   'county_name': 'BULLOCK',
#   'state': 'AL',
#   'dem_votes': 726,
#   'dem_nominee': 'Alton B. Parker',
#   'rep_votes': 0,
#   'rep_nominee': 'Theodore Roosevelt',
#   'county_end_date': nan},
#  {'election_year': 1908,
#   'fips': 1011.0,
#   'county_name': 'BULLOCK',
#   'state': 'AL',
#   'dem_votes': 782,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 10,
#   'rep_nominee': 'William Howard Taft',
#   'county_end_date': nan},
#  {'election_year': 1912,
#   'fips': 1011.0,
#   'county_name': 'BULLOCK',
#   'state': 'AL',
#   'dem_votes': 736,
#   'dem_nominee': 'Woodrow Wilson',
#   'rep_votes': 4,
#   'rep_nominee': 'William Howard Taft',
#   'county_end_date': nan},
#  {'election_year': 1916,
#   'fips': 1011.0,
#   'county_name': 'BULLOCK',
#   'state': 'AL',
#   'dem_votes': 743,
#   'dem_nominee': 'Woodrow Wilson',
#   'rep_votes': 4,
#   'rep_nominee': 'Charles Evan Hughes',
#   'county_end_date': nan},
#  {'election_year': 1920,
#   'fips': 1011.0,
#   'county_name': 'BULLOCK',
#   'state': 'AL',
#   'dem_votes': 877,
#   'dem_nominee': 'James M. Cox',
#   'rep_votes': 2,
#   'rep_nominee': 'Warren G. Harding',
#   'county_end_date': nan},
#  {'election_year': 1924,
#   'fips': 1011.0,
#   'county_name': 'BULLOCK',
#   'state': 'AL',
# ...
#   'rep_votes': 6288,
#   'rep_nominee': 'Mitt Romney',
#   'county_end_date': nan},
#  {'election_year': 2016,
#   'fips': 1047.0,
#   'county_name': 'DALLAS',
#   'state': 'AL',
#   'dem_votes': 12836,
#   'dem_nominee': 'Hillary Rodham Clinton',
#   'rep_votes': 5789,
#   'rep_nominee': 'Donald Trump',
#   'county_end_date': nan},
#  {'election_year': 2020,
#   'fips': 1047.0,
#   'county_name': 'DALLAS',
#   'state': 'AL',
#   'dem_votes': 12230,
#   'dem_nominee': 'Joe Biden',
#   'rep_votes': 5524,
#   'rep_nominee': 'Donald Trump',
#   'county_end_date': nan},
#  {'election_year': 1868,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 360,
#   'dem_nominee': 'Horatio Seymour',
#   'rep_votes': 492,
#   'rep_nominee': 'Ulysses S. Grant',
#   'county_end_date': nan},
#  {'election_year': 1872,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 576,
#   'dem_nominee': 'Horace Greeley',
#   'rep_votes': 585,
#   'rep_nominee': 'Ulysses S. Grant',
#   'county_end_date': nan},
#  {'election_year': 1876,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 987,
#   'dem_nominee': 'Samuel J. Tilden',
#   'rep_votes': 477,
#   'rep_nominee': 'Rutherford B. Hayes',
#   'county_end_date': nan},
#  {'election_year': 1880,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 759,
#   'dem_nominee': 'Winfield Scott Hancock',
#   'rep_votes': 252,
#   'rep_nominee': 'James A. Garfield',
#   'county_end_date': nan},
#  {'election_year': 1884,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 1077,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 465,
#   'rep_nominee': 'James G. Blaine',
#   'county_end_date': nan},
#  {'election_year': 1888,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 1326,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 593,
#   'rep_nominee': 'Benjamin Harrison',
#   'county_end_date': nan},
#  {'election_year': 1892,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 1868,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 5,
#   'rep_nominee': 'Benjamin Harrison',
#   'county_end_date': nan},
#  {'election_year': 1896,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 1365,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 1446,
#   'rep_nominee': 'William McKinley',
#   'county_end_date': nan},
#  {'election_year': 1900,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 1873,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 1735,
#   'rep_nominee': 'William McKinley',
#   'county_end_date': nan},
#  {'election_year': 1904,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 1716,
#   'dem_nominee': 'Alton B. Parker',
#   'rep_votes': 1237,
#   'rep_nominee': 'Theodore Roosevelt',
#   'county_end_date': nan},
#  {'election_year': 1908,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 1395,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 1103,
#   'rep_nominee': 'William Howard Taft',
#   'county_end_date': nan},
#  {'election_year': 1912,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 1379,
#   'dem_nominee': 'Woodrow Wilson',
#   'rep_votes': 492,
#   'rep_nominee': 'William Howard Taft',
#   'county_end_date': nan},
#  {'election_year': 1916,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 1787,
#   'dem_nominee': 'Woodrow Wilson',
#   'rep_votes': 1190,
#   'rep_nominee': 'Charles Evan Hughes',
#   'county_end_date': nan},
#  {'election_year': 1920,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 3894,
#   'dem_nominee': 'James M. Cox',
#   'rep_votes': 4852,
#   'rep_nominee': 'Warren G. Harding',
#   'county_end_date': nan},
#  {'election_year': 1924,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 3003,
#   'dem_nominee': 'John W. Davis',
#   'rep_votes': 3434,
#   'rep_nominee': 'Calvin Cooldige',
#   'county_end_date': nan},
#  {'election_year': 1928,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 3957,
#   'dem_nominee': 'Al Smith',
#   'rep_votes': 5761,
#   'rep_nominee': 'Herbert Hoover',
#   'county_end_date': nan},
#  {'election_year': 1932,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 4217,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 3496,
#   'rep_nominee': 'Herbert Hoover',
#   'county_end_date': nan},
#  {'election_year': 1936,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 6120,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 4620,
#   'rep_nominee': 'Alf Landon',
#   'county_end_date': nan},
#  {'election_year': 1940,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 5432,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 2810,
#   'rep_nominee': 'Wendell Willkie',
#   'county_end_date': nan},
#  {'election_year': 1944,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 4366,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 2627,
#   'rep_nominee': 'Thomes E. Dewey',
#   'county_end_date': nan},
#  {'election_year': 1948,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 3573,
#   'dem_nominee': 'Harry S. Truman',
#   'rep_votes': 2743,
#   'rep_nominee': 'Thomes E. Dewey',
#   'county_end_date': nan},
#  {'election_year': 1952,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 5209,
#   'dem_nominee': 'Adlai Stevenson II',
#   'rep_votes': 3997,
#   'rep_nominee': 'Dwight D. Eisenhower',
#   'county_end_date': nan},
#  {'election_year': 1956,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 5768,
#   'dem_nominee': 'Adlai Stevenson II',
#   'rep_votes': 5684,
#   'rep_nominee': 'Dwight D. Eisenhower',
#   'county_end_date': nan},
#  {'election_year': 1960,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 5844,
#   'dem_nominee': 'John F. Kennedy',
#   'rep_votes': 5581,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1964,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 4948,
#   'dem_nominee': 'Lyndon B. Johnson',
#   'rep_votes': 6746,
#   'rep_nominee': 'Barry Goldwater',
#   'county_end_date': nan},
#  {'election_year': 1968,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 8089,
#   'dem_nominee': 'Herbert H. Humphrey',
#   'rep_votes': 5364,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1972,
#   'fips': 1049.0,
#   'county_name': 'DEKALB',
#   'state': 'AL',
#   'dem_votes': 3759,
#   'dem_nominee': 'George S. McGovern',
#   'rep_votes': 9434,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1976,
#   'fips': 1049.0,
#   'county_name': 'DEKALB',
#   'state': 'AL',
#   'dem_votes': 9759,
#   'dem_nominee': 'Jimmy Carter',
#   'rep_votes': 6597,
#   'rep_nominee': 'Gerald Ford',
#   'county_end_date': nan},
#  {'election_year': 1980,
#   'fips': 1049.0,
#   'county_name': 'DEKALB',
#   'state': 'AL',
#   'dem_votes': 8820,
#   'dem_nominee': 'Jimmy Carter',
#   'rep_votes': 9673,
#   'rep_nominee': 'Ronald Reagan',
#   'county_end_date': nan},
#  {'election_year': 1984,
#   'fips': 1049.0,
#   'county_name': 'DEKALB',
#   'state': 'AL',
#   'dem_votes': 7212,
#   'dem_nominee': 'Walter Mondale',
#   'rep_votes': 12098,
#   'rep_nominee': 'Ronald Reagan',
#   'county_end_date': nan},
#  {'election_year': 1988,
#   'fips': 1049.0,
#   'county_name': 'DEKALB',
#   'state': 'AL',
#   'dem_votes': 7333,
#   'dem_nominee': 'Michael Dukakis',
#   'rep_votes': 11478,
#   'rep_nominee': 'George H.W. Bush',
#   'county_end_date': nan},
#  {'election_year': 1992,
#   'fips': 1049.0,
#   'county_name': 'DEKALB',
#   'state': 'AL',
#   'dem_votes': 8245,
#   'dem_nominee': 'Bill Clinton',
#   'rep_votes': 10519,
#   'rep_nominee': 'George H.W. Bush',
#   'county_end_date': nan},
#  {'election_year': 1996,
#   'fips': 1049.0,
#   'county_name': 'DEKALB',
#   'state': 'AL',
#   'dem_votes': 6544,
#   'dem_nominee': 'Bill Clinton',
#   'rep_votes': 9823,
#   'rep_nominee': 'Bob Dole',
#   'county_end_date': nan},
#  {'election_year': 2000,
#   'fips': 1049.0,
#   'county_name': 'DEKALB',
#   'state': 'AL',
#   'dem_votes': 7056,
#   'dem_nominee': 'Al Gore',
#   'rep_votes': 12827,
#   'rep_nominee': 'George W. Bush',
#   'county_end_date': nan},
#  {'election_year': 2004,
#   'fips': 1049.0,
#   'county_name': 'DEKALB',
#   'state': 'AL',
#   'dem_votes': 7092,
#   'dem_nominee': 'John F. Kerry',
#   'rep_votes': 16904,
#   'rep_nominee': 'George W. Bush',
#   'county_end_date': nan},
#  {'election_year': 2008,
#   'fips': 1049.0,
#   'county_name': 'DEKALB',
#   'state': 'AL',
#   'dem_votes': 5658,
#   'dem_nominee': 'Barack H. Obama',
#   'rep_votes': 17957,
#   'rep_nominee': 'John McCain',
#   'county_end_date': nan},
#  {'election_year': 2012,
#   'fips': 1049.0,
#   'county_name': 'DEKALB',
#   'state': 'AL',
#   'dem_votes': 5239,
#   'dem_nominee': 'Barack H. Obama',
#   'rep_votes': 18331,
#   'rep_nominee': 'Mitt Romney',
#   'county_end_date': nan},
#  {'election_year': 2016,
#   'fips': 1049.0,
#   'county_name': 'DEKALB',
#   'state': 'AL',
#   'dem_votes': 3622,
#   'dem_nominee': 'Hillary Rodham Clinton',
#   'rep_votes': 21405,
#   'rep_nominee': 'Donald Trump',
#   'county_end_date': nan},
#  {'election_year': 2020,
#   'fips': 1049.0,
#   'county_name': 'DE KALB',
#   'state': 'AL',
#   'dem_votes': 4281,
#   'dem_nominee': 'Joe Biden',
#   'rep_votes': 24767,
#   'rep_nominee': 'Donald Trump',
#   'county_end_date': nan},
#  {'election_year': 1868,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1197,
#   'dem_nominee': 'Horatio Seymour',
#   'rep_votes': 1262,
#   'rep_nominee': 'Ulysses S. Grant',
#   'county_end_date': nan},
#  {'election_year': 1872,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1309,
#   'dem_nominee': 'Horace Greeley',
#   'rep_votes': 1564,
#   'rep_nominee': 'Ulysses S. Grant',
#   'county_end_date': nan},
#  {'election_year': 1876,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1399,
#   'dem_nominee': 'Samuel J. Tilden',
#   'rep_votes': 1249,
#   'rep_nominee': 'Rutherford B. Hayes',
#   'county_end_date': nan},
#  {'election_year': 1880,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1467,
#   'dem_nominee': 'Winfield Scott Hancock',
#   'rep_votes': 1389,
#   'rep_nominee': 'James A. Garfield',
#   'county_end_date': nan},
#  {'election_year': 1884,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1452,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 1141,
#   'rep_nominee': 'James G. Blaine',
#   'county_end_date': nan},
#  {'election_year': 1888,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1717,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 1535,
#   'rep_nominee': 'Benjamin Harrison',
#   'county_end_date': nan},
#  {'election_year': 1892,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1258,
#   'dem_nominee': 'Grover Cleveland',
#   'rep_votes': 84,
#   'rep_nominee': 'Benjamin Harrison',
#   'county_end_date': nan},
#  {'election_year': 1896,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1182,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 1379,
#   'rep_nominee': 'William McKinley',
#   'county_end_date': nan},
#  {'election_year': 1900,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1773,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 1104,
#   'rep_nominee': 'William McKinley',
#   'county_end_date': nan},
#  {'election_year': 1904,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1226,
#   'dem_nominee': 'Alton B. Parker',
#   'rep_votes': 151,
#   'rep_nominee': 'Theodore Roosevelt',
#   'county_end_date': nan},
#  {'election_year': 1908,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1063,
#   'dem_nominee': 'William Jennings Bryan',
#   'rep_votes': 138,
#   'rep_nominee': 'William Howard Taft',
#   'county_end_date': nan},
#  {'election_year': 1912,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1152,
#   'dem_nominee': 'Woodrow Wilson',
#   'rep_votes': 81,
#   'rep_nominee': 'William Howard Taft',
#   'county_end_date': nan},
#  {'election_year': 1916,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1631,
#   'dem_nominee': 'Woodrow Wilson',
#   'rep_votes': 7,
#   'rep_nominee': 'Charles Evan Hughes',
#   'county_end_date': nan},
#  {'election_year': 1920,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1762,
#   'dem_nominee': 'James M. Cox',
#   'rep_votes': 353,
#   'rep_nominee': 'Warren G. Harding',
#   'county_end_date': nan},
#  {'election_year': 1924,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1088,
#   'dem_nominee': 'John W. Davis',
#   'rep_votes': 219,
#   'rep_nominee': 'Calvin Cooldige',
#   'county_end_date': nan},
#  {'election_year': 1928,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1309,
#   'dem_nominee': 'Al Smith',
#   'rep_votes': 1770,
#   'rep_nominee': 'Herbert Hoover',
#   'county_end_date': nan},
#  {'election_year': 1932,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 3197,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 159,
#   'rep_nominee': 'Herbert Hoover',
#   'county_end_date': nan},
#  {'election_year': 1936,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 3967,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 182,
#   'rep_nominee': 'Alf Landon',
#   'county_end_date': nan},
#  {'election_year': 1940,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 4267,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 144,
#   'rep_nominee': 'Wendell Willkie',
#   'county_end_date': nan},
#  {'election_year': 1944,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 3109,
#   'dem_nominee': 'Franklin Delano Roosevelt',
#   'rep_votes': 185,
#   'rep_nominee': 'Thomes E. Dewey',
#   'county_end_date': nan},
#  {'election_year': 1948,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 2387,
#   'dem_nominee': 'Harry S. Truman',
#   'rep_votes': 167,
#   'rep_nominee': 'Thomes E. Dewey',
#   'county_end_date': nan},
#  {'election_year': 1952,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 4199,
#   'dem_nominee': 'Adlai Stevenson II',
#   'rep_votes': 1315,
#   'rep_nominee': 'Dwight D. Eisenhower',
#   'county_end_date': nan},
#  {'election_year': 1956,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 3318,
#   'dem_nominee': 'Adlai Stevenson II',
#   'rep_votes': 1619,
#   'rep_nominee': 'Dwight D. Eisenhower',
#   'county_end_date': nan},
#  {'election_year': 1960,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 3440,
#   'dem_nominee': 'John F. Kennedy',
#   'rep_votes': 1910,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1964,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1233,
#   'dem_nominee': 'Lyndon B. Johnson',
#   'rep_votes': 6363,
#   'rep_nominee': 'Barry Goldwater',
#   'county_end_date': nan},
#  {'election_year': 1968,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 8998,
#   'dem_nominee': 'Herbert H. Humphrey',
#   'rep_votes': 823,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1972,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 1891,
#   'dem_nominee': 'George S. McGovern',
#   'rep_votes': 8461,
#   'rep_nominee': 'Richard M. Nixon',
#   'county_end_date': nan},
#  {'election_year': 1976,
#   'fips': 1051.0,
#   'county_name': 'ELMORE',
#   'state': 'AL',
#   'dem_votes': 6646,
#   'dem_nominee': 'Jimmy Carter',
#   'rep_votes': 6551,
#   'rep_nominee': 'Gerald Ford',
#   'county_end_date': nan},
#  ...]
